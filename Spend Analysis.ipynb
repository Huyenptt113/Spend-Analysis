# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
th_2020 = pd.read_csv('th_data_2020.csv',sep='\t')
th_2021 = pd.read_csv('th_data_2021.csv',sep='\t')
# Out:
# /opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (0,6,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
th_2020 = th_2020[th_2020['hankintayksikko'] =='Terveyden ja hyvinvoinnin laitos']
th_2021 = th_2021[th_2021['hankintayksikko'] =='Terveyden ja hyvinvoinnin laitos']

# %%
th = pd.concat([th_2020,th_2021])
th.head()
# Out:
#       lasku_id                   tili  tiliointisumma   tositepvm  \
# 1991  20440119  42090000 Muut vuokrat            40.0  01.04.2020
# 1992  20440120  42090000 Muut vuokrat            40.0  01.01.2020
# 1993  20440121  42090000 Muut vuokrat            40.0  01.06.2020
# 1994  20440122  42090000 Muut vuokrat            40.0  01.03.2020
# 1995  20440123  42090000 Muut vuokrat            40.0  01.02.2020
#
#      toimittaja_y_tunnus       toimittaja_nimi hankintayksikko_tunnus  \
# 1991           0864079-0  Kiinteistö Oy F-Medi                    561
# 1992           0864079-0  Kiinteistö Oy F-Medi                    561
# 1993           0864079-0  Kiinteistö Oy F-Medi                    561
# 1994           0864079-0  Kiinteistö Oy F-Medi                    561
# 1995           0864079-0  Kiinteistö Oy F-Medi                    561
#
#                        hankintayksikko ylaorganisaatio_tunnus  \
# 1991  Terveyden ja hyvinvoinnin laitos                     33
# ...

# %%
th.columns = ['invoice_id', 'account', 'account amount', 'voucher date', 'supplier_y_id', 'supplier_name', 'supplier_id', 'vendor', 'parent organization_id', 'parent organization', 'sector', 'product_service group', 'procurement category']

# %%
th_2020.columns = ['invoice_id', 'account', 'account amount', 'voucher date', 'supplier_y_id', 'supplier_name', 'supplier_id', 'vendor', 'parent organization_id', 'parent organization', 'sector', 'product_service group', 'procurement category']

# %%
th_2021.columns = ['invoice_id', 'account', 'account amount', 'voucher date', 'supplier_y_id', 'supplier_name', 'supplier_id', 'vendor', 'parent organization_id', 'parent organization', 'sector', 'product_service group', 'procurement category']

# %%
th.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100641 entries, 1991 to 681593
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   invoice_id              100641 non-null  object
#  1   account                 100641 non-null  object
#  2   account amount          100641 non-null  float64
#  3   voucher date            100641 non-null  object
#  4   supplier_y_id           100306 non-null  object
#  5   supplier_name           100641 non-null  object
#  6   supplier_id             100641 non-null  object
#  7   vendor                  100641 non-null  object
#  8   parent organization_id  100641 non-null  object
#  9   parent organization     100641 non-null  object
#  10  sector                  100641 non-null  object
#  11  product_service group   100641 non-null  object
#  12  procurement category    100641 non-null  object
# dtypes: float64(1), object(12)
# ...

# %%
th.describe()
# Out:
#        account amount
# count    1.006410e+05
# mean     3.959867e+03
# std      7.631194e+04
# min     -2.624000e+06
# 25%      4.226000e+01
# 50%      1.749500e+02
# 75%      6.826900e+02
# max      1.536662e+07

# %%
th.head(3)
# Out:
#      invoice_id                account  account amount voucher date  \
# 1991   20440119  42090000 Muut vuokrat            40.0   01.04.2020
# 1992   20440120  42090000 Muut vuokrat            40.0   01.01.2020
# 1993   20440121  42090000 Muut vuokrat            40.0   01.06.2020
#
#      supplier_y_id         supplier_name supplier_id  \
# 1991     0864079-0  Kiinteistö Oy F-Medi         561
# 1992     0864079-0  Kiinteistö Oy F-Medi         561
# 1993     0864079-0  Kiinteistö Oy F-Medi         561
#
#                                 vendor parent organization_id  \
# 1991  Terveyden ja hyvinvoinnin laitos                     33
# 1992  Terveyden ja hyvinvoinnin laitos                     33
# 1993  Terveyden ja hyvinvoinnin laitos                     33
#
#                                parent organization  sector  \
# 1991  Sosiaali- ja terveysministeriön hallinnonala  Valtio
# 1992  Sosiaali- ja terveysministeriön hallinnonala  Valtio
# ...

# %%
th_2020 = th_2020.drop(columns = ['parent organization','supplier_id','parent organization_id','sector'])

# %%
th_2021 = th_2021.drop(columns = ['parent organization','supplier_id','parent organization_id','sector'])

# %%
th = th.drop(columns = ['parent organization','supplier_id','parent organization_id','sector'])

# %%
th_2020=th_2020.replace(['Terveyden ja hyvinvoinnin laitos','hankintakategoria','Asiakaspalvelujen ostot',"Asiantuntija- ja toimistopalvelut",
                 "Rakennusten ja alueiden ylläpito",
'ICT-hankinnat (tavarat, palvelut ja ohjelmistot)',
'Hallinnolliset palvelut',
'Rakentaminen',
'Koneet, laitteet ja kuljetusvälineet',
'Majoitus- ja ravitsemispalvelut',
'Matkustus- ja kuljetuspalvelut',
'Sosiaali- ja terveyspalvelut',
'Koulutus- ja kulttuuripalvelut',
'Käyttöomaisuushankinnat',
'Aineet, tarvikkeet ja tavarat',
'Alueet ja väylät',
'Henkilöstöpalvelut',
'Maanpuolustuskalusto',
], ['National Institute for Health and Welfare','ankintakategoria_en',
'Customer service purchases',
'Expert and office services',
'Building and area maintenance',
'ICT procurement',
'Administrative services',
'Construction',
'Machinery, equipment and vehicles',
'Accommodation and catering services',
'Travel and transportation services',
'Social and health services',
'Educational and cultural services',
'Fixed asset procurements',
'Materials, goods and supplies',
'Areas and routes',
'Human resource services',
'National defence equipment'
])

# %%
th_2021=th_2021.replace(['Terveyden ja hyvinvoinnin laitos','hankintakategoria','Asiakaspalvelujen ostot',"Asiantuntija- ja toimistopalvelut",
                 "Rakennusten ja alueiden ylläpito",
'ICT-hankinnat (tavarat, palvelut ja ohjelmistot)',
'Hallinnolliset palvelut',
'Rakentaminen',
'Koneet, laitteet ja kuljetusvälineet',
'Majoitus- ja ravitsemispalvelut',
'Matkustus- ja kuljetuspalvelut',
'Sosiaali- ja terveyspalvelut',
'Koulutus- ja kulttuuripalvelut',
'Käyttöomaisuushankinnat',
'Aineet, tarvikkeet ja tavarat',
'Alueet ja väylät',
'Henkilöstöpalvelut',
'Maanpuolustuskalusto',
], ['National Institute for Health and Welfare','hankintakategoria_en',
'Customer service purchases',
'Expert and office services',
'Building and area maintenance',
'ICT procurement',
'Administrative services',
'Construction',
'Machinery, equipment and vehicles',
'Accommodation and catering services',
'Travel and transportation services',
'Social and health services',
'Educational and cultural services',
'Fixed asset procurements',
'Materials, goods and supplies',
'Areas and routes',
'Human resource services',
'National defence equipment'
])

# %%
th=th.replace(['Terveyden ja hyvinvoinnin laitos','hankintakategoria','Asiakaspalvelujen ostot',"Asiantuntija- ja toimistopalvelut",
                 "Rakennusten ja alueiden ylläpito",
'ICT-hankinnat (tavarat, palvelut ja ohjelmistot)',
'Hallinnolliset palvelut',
'Rakentaminen',
'Koneet, laitteet ja kuljetusvälineet',
'Majoitus- ja ravitsemispalvelut',
'Matkustus- ja kuljetuspalvelut',
'Sosiaali- ja terveyspalvelut',
'Koulutus- ja kulttuuripalvelut',
'Käyttöomaisuushankinnat',
'Aineet, tarvikkeet ja tavarat',
'Alueet ja väylät',
'Henkilöstöpalvelut',
'Maanpuolustuskalusto',
], ['National Institute for Health and Welfare','hankintakategoria_en',
'Customer service purchases',
'Expert and office services',
'Building and area maintenance',
'ICT procurement',
'Administrative services',
'Construction',
'Machinery, equipment and vehicles',
'Accommodation and catering services',
'Travel and transportation services',
'Social and health services',
'Educational and cultural services',
'Fixed asset procurements',
'Materials, goods and supplies',
'Areas and routes',
'Human resource services',
'National defence equipment'
])

# %%
th=th.replace(['Arvo- ja taide-esineet',
'Arvoltaan vähäiset koneet, kalusteet ja kuljetusvälineet',
'Asiakaspalvelujen ostot',
'Asiantuntija- ja tutkimuspalvelut',
'Elintarvikkeet, juomat ja tupakka',
'Ennakkomaksut ja keskeneräiset hankinnat',
'Henkilöstön koulutuspalvelut',
'Henkilöstön matkustus- ja kuljetuspalvelut',
'Henkilöstön ravitsemispalvelut',
'Henkilöstön työterveyspalvelut',
'Henkilöstön virkistyspalvelut',
'Henkilöstövuokrauspalvelut',
'Hoitotarvikkeet',
'ICT-laitteet',
'ICT-palvelut',
'Jäsenmaksut',
'Jätehuolto',
'Käännös- ja tulkkauspalvelut',
'Kalusteet',
'Käyttöomaisuushankinnat',
'Kirjat, lehdet ja muut painotuotteet',
'Koneet, laitteet ja kalusto',
'Koneiden, laitteiden ja kaluston kunnossapitopalvelut',
'Koneiden, laitteiden ja kuljetusvälineiden vuokrat',
'Koulutus- ja kulttuuripalvelut',
'Kuljetuspalvelut',
'Kuljetusvälineet',
'Kunnossapitopalvelut',
'Kuvantamispalvelut',
'Lääkkeet ja lääkevalmisteet',
'Lääkkeet, hoitoaineet ja -tarvikkeet',
'Laboratoriopalvelut',
'Lämmitys',
'Lämmitys, sähkö ja vesi',
'Maa- ja vesialueet',
'Maa- ja vesialueiden vuokrat',
'Maanpuolustuskalusto',
'Maanvuokrat',
'Majoitus- ja ravitsemispalvelut',
'Majoituspalvelut',
'Matkustuspalvelut',
'Muut aineet, tarvikkeet ja tavarat',
'Muut asiantuntija- ja toimistopalvelut',
'Muut henkilöstöpalvelut',
'Muut hoito- ja terapiatarvikkeet',
'Muut hyödykkeet',
'Muut kulut',
'Muut kustannusten korvaukset',
'Muut matkustus- ja kuljetuspalvelut',
'Muut palvelut',
'Muut pitkävaikutteiset menot',
'Muut sosiaali- ja terveyspalvelut',
'Muut tutkimus- ja kehittämismenot',
'Muut vuokrat',
'Ohjelmistot ja aineettomat oikeudet',
'Osakehankinnat',
'Painatukset, ilmoitukset ja markkinointi',
'Poltto- ja voiteluaineet',
'Posti- ja kuriiripalvelut',
'Puhdistusaineet ja -tarvikkeet',
'Puhtaanapito- ja pesulapalvelut',
'Rahoitus- ja pankkipalvelut',
'Rakennelmat',
'Rakennukset',
'Rakennusmateriaali',
'Rakennusten ja huoneistojen vuokrat',
'Rakentamis-, korjaus- ja kunnossapitopalvelut',
'Rakenteet',
'Ravitsemispalvelut',
'Sähkö ja kaasu',
'Sosiaali- ja terveyspalvelut',
'Talous- ja henkilöstöhallinnon palvelujen ostot valtion virastoilta ja laitoksilta',
'Tilintarkastus- ja veropalvelut',
'Toimisto- ja koulutarvikkeet',
'tuote_palveluryhma',
'Työterveyspalvelut',
'Vaatteisto',
'Vakuutukset ja vahinkomaksut',
'Varaosat',
'Vartiointi- ja turvallisuuspalvelut',
'Väylähankkeet',
'Vesi',
'Yhteistoimintaosuudet'],['Valuables and works of art',
'Machinery, furniture and transport equipment of minor value',
'Customer service purchases',
'Expert and research services',
'Foodstuff, drinks and tobacco',
'Advance payments and incomplete procurements',
'Staff training services',
'Staff travel and transportation services',
'Staff catering services',
'Staff health services',
'Staff recreational services',
'Temporary staffing services',
'Medical care products and supplies',
'IT equipment and peripherals',
'ICT services',
'Membership fees',
'Waste management',
'Translation and interpretation services',
'Furniture',
'Fixed asset procurements',
'Books, magazines and other print products',
'Machinery, devices and equipment',
'Maintenance services for machinery, devices and equipment',
'Rental expenses for machinery, devices and equipment',
'Educational and cultural services',
'Transportation services',
'Transportation equipment',
'Maintenance services',
'Medical imaging services',
'Medicine',
'Medicine, medical care products and supplies',
'Laboratory services',
'Heating',
'Heating, electricity and water',
'Land and water areas',
'Land and water area rents',
'National defence equipment',
'Land rent',
'Accommodation and catering services',
'Accommodation services',
'Travel services',
'Other substances, supplies and goods',
'Other expert and office services',
'Other HR services',
'Other treatment and therapy supplies',
'Other goods',
'Other costs',
'Other reimbursements of costs',
'Other travel and transportation services',
'Other services',
'Other long-term expenses',
'Other social and health services',
'Other research and development expenses',
'Other rent',
'Software and intellectual property rights',
'Share purchases',
'Printing, announcements, and marketing',
'Fuel and lubricants',
'Postal and courier services',
'Cleaning substances and supplies',
'Sanitation and laundry services',
'Financing and banking services',
'Built structures',
'Buildings',
'Building material',
'Building and apartment rents',
'Construction, repair and maintenance services',
'Structures',
'Nutrition services',
'Electricity and gas',
'Social and health services',
'Financial and HR service purchases from state agencies',
'Audit and tax services',
'Office and school supplies',
'tuote_palveluryhma_en',
'Occupational health services',
'Clothing',
'Insurances and damage payments',
'Spare parts',
'Security services',
'Transport infrastructure projects',
'Water',
'Joint activity shares'])

# %%
th_2020=th_2020.replace(['Arvo- ja taide-esineet',
'Arvoltaan vähäiset koneet, kalusteet ja kuljetusvälineet',
'Asiakaspalvelujen ostot',
'Asiantuntija- ja tutkimuspalvelut',
'Elintarvikkeet, juomat ja tupakka',
'Ennakkomaksut ja keskeneräiset hankinnat',
'Henkilöstön koulutuspalvelut',
'Henkilöstön matkustus- ja kuljetuspalvelut',
'Henkilöstön ravitsemispalvelut',
'Henkilöstön työterveyspalvelut',
'Henkilöstön virkistyspalvelut',
'Henkilöstövuokrauspalvelut',
'Hoitotarvikkeet',
'ICT-laitteet',
'ICT-palvelut',
'Jäsenmaksut',
'Jätehuolto',
'Käännös- ja tulkkauspalvelut',
'Kalusteet',
'Käyttöomaisuushankinnat',
'Kirjat, lehdet ja muut painotuotteet',
'Koneet, laitteet ja kalusto',
'Koneiden, laitteiden ja kaluston kunnossapitopalvelut',
'Koneiden, laitteiden ja kuljetusvälineiden vuokrat',
'Koulutus- ja kulttuuripalvelut',
'Kuljetuspalvelut',
'Kuljetusvälineet',
'Kunnossapitopalvelut',
'Kuvantamispalvelut',
'Lääkkeet ja lääkevalmisteet',
'Lääkkeet, hoitoaineet ja -tarvikkeet',
'Laboratoriopalvelut',
'Lämmitys',
'Lämmitys, sähkö ja vesi',
'Maa- ja vesialueet',
'Maa- ja vesialueiden vuokrat',
'Maanpuolustuskalusto',
'Maanvuokrat',
'Majoitus- ja ravitsemispalvelut',
'Majoituspalvelut',
'Matkustuspalvelut',
'Muut aineet, tarvikkeet ja tavarat',
'Muut asiantuntija- ja toimistopalvelut',
'Muut henkilöstöpalvelut',
'Muut hoito- ja terapiatarvikkeet',
'Muut hyödykkeet',
'Muut kulut',
'Muut kustannusten korvaukset',
'Muut matkustus- ja kuljetuspalvelut',
'Muut palvelut',
'Muut pitkävaikutteiset menot',
'Muut sosiaali- ja terveyspalvelut',
'Muut tutkimus- ja kehittämismenot',
'Muut vuokrat',
'Ohjelmistot ja aineettomat oikeudet',
'Osakehankinnat',
'Painatukset, ilmoitukset ja markkinointi',
'Poltto- ja voiteluaineet',
'Posti- ja kuriiripalvelut',
'Puhdistusaineet ja -tarvikkeet',
'Puhtaanapito- ja pesulapalvelut',
'Rahoitus- ja pankkipalvelut',
'Rakennelmat',
'Rakennukset',
'Rakennusmateriaali',
'Rakennusten ja huoneistojen vuokrat',
'Rakentamis-, korjaus- ja kunnossapitopalvelut',
'Rakenteet',
'Ravitsemispalvelut',
'Sähkö ja kaasu',
'Sosiaali- ja terveyspalvelut',
'Talous- ja henkilöstöhallinnon palvelujen ostot valtion virastoilta ja laitoksilta',
'Tilintarkastus- ja veropalvelut',
'Toimisto- ja koulutarvikkeet',
'tuote_palveluryhma',
'Työterveyspalvelut',
'Vaatteisto',
'Vakuutukset ja vahinkomaksut',
'Varaosat',
'Vartiointi- ja turvallisuuspalvelut',
'Väylähankkeet',
'Vesi',
'Yhteistoimintaosuudet'],['Valuables and works of art',
'Machinery, furniture and transport equipment of minor value',
'Customer service purchases',
'Expert and research services',
'Foodstuff, drinks and tobacco',
'Advance payments and incomplete procurements',
'Staff training services',
'Staff travel and transportation services',
'Staff catering services',
'Staff health services',
'Staff recreational services',
'Temporary staffing services',
'Medical care products and supplies',
'IT equipment and peripherals',
'ICT services',
'Membership fees',
'Waste management',
'Translation and interpretation services',
'Furniture',
'Fixed asset procurements',
'Books, magazines and other print products',
'Machinery, devices and equipment',
'Maintenance services for machinery, devices and equipment',
'Rental expenses for machinery, devices and equipment',
'Educational and cultural services',
'Transportation services',
'Transportation equipment',
'Maintenance services',
'Medical imaging services',
'Medicine',
'Medicine, medical care products and supplies',
'Laboratory services',
'Heating',
'Heating, electricity and water',
'Land and water areas',
'Land and water area rents',
'National defence equipment',
'Land rent',
'Accommodation and catering services',
'Accommodation services',
'Travel services',
'Other substances, supplies and goods',
'Other expert and office services',
'Other HR services',
'Other treatment and therapy supplies',
'Other goods',
'Other costs',
'Other reimbursements of costs',
'Other travel and transportation services',
'Other services',
'Other long-term expenses',
'Other social and health services',
'Other research and development expenses',
'Other rent',
'Software and intellectual property rights',
'Share purchases',
'Printing, announcements, and marketing',
'Fuel and lubricants',
'Postal and courier services',
'Cleaning substances and supplies',
'Sanitation and laundry services',
'Financing and banking services',
'Built structures',
'Buildings',
'Building material',
'Building and apartment rents',
'Construction, repair and maintenance services',
'Structures',
'Nutrition services',
'Electricity and gas',
'Social and health services',
'Financial and HR service purchases from state agencies',
'Audit and tax services',
'Office and school supplies',
'tuote_palveluryhma_en',
'Occupational health services',
'Clothing',
'Insurances and damage payments',
'Spare parts',
'Security services',
'Transport infrastructure projects',
'Water',
'Joint activity shares'])

# %%
th_2021=th_2021.replace(['Arvo- ja taide-esineet',
'Arvoltaan vähäiset koneet, kalusteet ja kuljetusvälineet',
'Asiakaspalvelujen ostot',
'Asiantuntija- ja tutkimuspalvelut',
'Elintarvikkeet, juomat ja tupakka',
'Ennakkomaksut ja keskeneräiset hankinnat',
'Henkilöstön koulutuspalvelut',
'Henkilöstön matkustus- ja kuljetuspalvelut',
'Henkilöstön ravitsemispalvelut',
'Henkilöstön työterveyspalvelut',
'Henkilöstön virkistyspalvelut',
'Henkilöstövuokrauspalvelut',
'Hoitotarvikkeet',
'ICT-laitteet',
'ICT-palvelut',
'Jäsenmaksut',
'Jätehuolto',
'Käännös- ja tulkkauspalvelut',
'Kalusteet',
'Käyttöomaisuushankinnat',
'Kirjat, lehdet ja muut painotuotteet',
'Koneet, laitteet ja kalusto',
'Koneiden, laitteiden ja kaluston kunnossapitopalvelut',
'Koneiden, laitteiden ja kuljetusvälineiden vuokrat',
'Koulutus- ja kulttuuripalvelut',
'Kuljetuspalvelut',
'Kuljetusvälineet',
'Kunnossapitopalvelut',
'Kuvantamispalvelut',
'Lääkkeet ja lääkevalmisteet',
'Lääkkeet, hoitoaineet ja -tarvikkeet',
'Laboratoriopalvelut',
'Lämmitys',
'Lämmitys, sähkö ja vesi',
'Maa- ja vesialueet',
'Maa- ja vesialueiden vuokrat',
'Maanpuolustuskalusto',
'Maanvuokrat',
'Majoitus- ja ravitsemispalvelut',
'Majoituspalvelut',
'Matkustuspalvelut',
'Muut aineet, tarvikkeet ja tavarat',
'Muut asiantuntija- ja toimistopalvelut',
'Muut henkilöstöpalvelut',
'Muut hoito- ja terapiatarvikkeet',
'Muut hyödykkeet',
'Muut kulut',
'Muut kustannusten korvaukset',
'Muut matkustus- ja kuljetuspalvelut',
'Muut palvelut',
'Muut pitkävaikutteiset menot',
'Muut sosiaali- ja terveyspalvelut',
'Muut tutkimus- ja kehittämismenot',
'Muut vuokrat',
'Ohjelmistot ja aineettomat oikeudet',
'Osakehankinnat',
'Painatukset, ilmoitukset ja markkinointi',
'Poltto- ja voiteluaineet',
'Posti- ja kuriiripalvelut',
'Puhdistusaineet ja -tarvikkeet',
'Puhtaanapito- ja pesulapalvelut',
'Rahoitus- ja pankkipalvelut',
'Rakennelmat',
'Rakennukset',
'Rakennusmateriaali',
'Rakennusten ja huoneistojen vuokrat',
'Rakentamis-, korjaus- ja kunnossapitopalvelut',
'Rakenteet',
'Ravitsemispalvelut',
'Sähkö ja kaasu',
'Sosiaali- ja terveyspalvelut',
'Talous- ja henkilöstöhallinnon palvelujen ostot valtion virastoilta ja laitoksilta',
'Tilintarkastus- ja veropalvelut',
'Toimisto- ja koulutarvikkeet',
'tuote_palveluryhma',
'Työterveyspalvelut',
'Vaatteisto',
'Vakuutukset ja vahinkomaksut',
'Varaosat',
'Vartiointi- ja turvallisuuspalvelut',
'Väylähankkeet',
'Vesi',
'Yhteistoimintaosuudet'],['Valuables and works of art',
'Machinery, furniture and transport equipment of minor value',
'Customer service purchases',
'Expert and research services',
'Foodstuff, drinks and tobacco',
'Advance payments and incomplete procurements',
'Staff training services',
'Staff travel and transportation services',
'Staff catering services',
'Staff health services',
'Staff recreational services',
'Temporary staffing services',
'Medical care products and supplies',
'IT equipment and peripherals',
'ICT services',
'Membership fees',
'Waste management',
'Translation and interpretation services',
'Furniture',
'Fixed asset procurements',
'Books, magazines and other print products',
'Machinery, devices and equipment',
'Maintenance services for machinery, devices and equipment',
'Rental expenses for machinery, devices and equipment',
'Educational and cultural services',
'Transportation services',
'Transportation equipment',
'Maintenance services',
'Medical imaging services',
'Medicine',
'Medicine, medical care products and supplies',
'Laboratory services',
'Heating',
'Heating, electricity and water',
'Land and water areas',
'Land and water area rents',
'National defence equipment',
'Land rent',
'Accommodation and catering services',
'Accommodation services',
'Travel services',
'Other substances, supplies and goods',
'Other expert and office services',
'Other HR services',
'Other treatment and therapy supplies',
'Other goods',
'Other costs',
'Other reimbursements of costs',
'Other travel and transportation services',
'Other services',
'Other long-term expenses',
'Other social and health services',
'Other research and development expenses',
'Other rent',
'Software and intellectual property rights',
'Share purchases',
'Printing, announcements, and marketing',
'Fuel and lubricants',
'Postal and courier services',
'Cleaning substances and supplies',
'Sanitation and laundry services',
'Financing and banking services',
'Built structures',
'Buildings',
'Building material',
'Building and apartment rents',
'Construction, repair and maintenance services',
'Structures',
'Nutrition services',
'Electricity and gas',
'Social and health services',
'Financial and HR service purchases from state agencies',
'Audit and tax services',
'Office and school supplies',
'tuote_palveluryhma_en',
'Occupational health services',
'Clothing',
'Insurances and damage payments',
'Spare parts',
'Security services',
'Transport infrastructure projects',
'Water',
'Joint activity shares'])

# %%
th.head()
# Out:
#       invoice_id                account  account amount voucher date  \
# 1991    20440119  42090000 Muut vuokrat            40.0   01.04.2020
# 1992    20440120  42090000 Muut vuokrat            40.0   01.01.2020
# 1993    20440121  42090000 Muut vuokrat            40.0   01.06.2020
# 1994    20440122  42090000 Muut vuokrat            40.0   01.03.2020
# 1995    20440123  42090000 Muut vuokrat            40.0   01.02.2020
#
#      supplier_y_id         supplier_name  \
# 1991     0864079-0  Kiinteistö Oy F-Medi
# 1992     0864079-0  Kiinteistö Oy F-Medi
# 1993     0864079-0  Kiinteistö Oy F-Medi
# 1994     0864079-0  Kiinteistö Oy F-Medi
# 1995     0864079-0  Kiinteistö Oy F-Medi
#
#                                          vendor product_service group  \
# 1991  National Institute for Health and Welfare            Other rent
# 1992  National Institute for Health and Welfare            Other rent
# 1993  National Institute for Health and Welfare            Other rent
# ...

# %%
th_2020.to_csv('translate_th_2020.csv')
th_2021.to_csv('translate_th_2021.csv')
th.to_csv('translate_th.csv')

# %%
# number of invoice each year
print('number of invoice in 2020:',th_2020['invoice_id'].nunique())
print('number of invoice in 2021:',th_2021['invoice_id'].nunique())
# Out:
# number of invoice in 2020: 30725
# number of invoice in 2021: 35238

# %%
# spend per invoice each year
print('number of invoice in 2020:',th_2020['account amount'].sum()/th_2020['invoice_id'].nunique())
print('number of invoice in 2021:',th_2021['account amount'].sum()/th_2021['invoice_id'].nunique())
# Out:
# number of invoice in 2020: 3911.4938763222135
# number of invoice in 2021: 7898.98150292298

# %%
# total spend each year
print('total spend in 2020:',th_2020['account amount'].sum())
print('total spend in 2021:',th_2021['account amount'].sum())
# Out:
# total spend in 2020: 120180649.35000001
# total spend in 2021: 278344310.2

# %%
# spend group by supplier in 2020

plt.figure(figsize =(15,10))
plt.subplot(221)
spend_supplier = th_2020.groupby('supplier_name')['account amount'].sum().sort_values(ascending=False).head(10)
spend_supplier.plot.bar()
plt.subplot(222)
spend_supplier2 = th_2021.groupby('supplier_name')['account amount'].sum().sort_values(ascending=False).head(10)
spend_supplier2.plot.bar()
plt.show()

# %%
# number of invoice group by supplier in 2020

plt.figure(figsize =(15,10))
plt.subplot(221)
spend_supplier = th_2020.groupby('supplier_name')['vendor'].value_counts().sort_values(ascending=False).head(10)
spend_supplier.plot.bar()
plt.subplot(222)
spend_supplier2 = th_2021.groupby('supplier_name')['vendor'].value_counts().sort_values(ascending=False).head(10)
spend_supplier2.plot.bar()
plt.show()

# %%
#Spend per supplier each year
print('Spend per supplier in 2020 is:',th_2020['account amount'].sum()/th_2020['supplier_name'].nunique())

print('Spend per supplier in 2021 is:',th_2021['account amount'].sum()/th_2021['supplier_name'].nunique())
# Out:
# Spend per supplier in 2020 is: 58998.84602356407
# Spend per supplier in 2021 is: 134791.43351089588

# %%
#number of supplier each year
print('number of supplier in 2020:',th_2020['supplier_name'].nunique())
print('number of supplier in 2021:',th_2021['supplier_name'].nunique())
# Out:
# number of supplier in 2020: 2037
# number of supplier in 2021: 2065

# %%
#spend by procurement category each year


plt.figure(figsize =(15,10))
plt.subplot(221)
th_2020.groupby('procurement category')['account amount'].sum().sort_values(ascending=False).head(10).plot.bar()
plt.subplot(222)
th_2021.groupby('procurement category')['account amount'].sum().sort_values(ascending=False).head(10).plot.bar()
plt.show()

# %%
#number of invoice by procurement category each year


plt.figure(figsize =(15,10))
plt.subplot(221)
th_2020.groupby('procurement category')['vendor'].value_counts().sort_values(ascending=False).head(10).plot.bar()
plt.subplot(222)
th_2021.groupby('procurement category')['vendor'].value_counts().sort_values(ascending=False).head(10).plot.bar()
plt.show()

# %%
#spend by procurement category each year


plt.figure(figsize =(15,10))
plt.subplot(221)
th_2020.groupby('procurement category')['account amount'].sum().plot.pie()
plt.subplot(222)
th_2021.groupby('procurement category')['account amount'].sum().plot.pie()
plt.show()

# %%
#spend by product each year


plt.figure(figsize =(15,10))
plt.subplot(221)
th_2020.groupby('product_service group')['account amount'].sum().sort_values(ascending=False).head(10).plot.bar()
plt.subplot(222)
th_2021.groupby('product_service group')['account amount'].sum().sort_values(ascending=False).head(10).plot.bar()
plt.show()

# %%
#number of invoice by procurement category each year


plt.figure(figsize =(15,10))
plt.subplot(221)
th_2020.groupby('product_service group')['vendor'].value_counts().sort_values(ascending=False).head(10).plot.bar()
plt.subplot(222)
th_2021.groupby('product_service group')['vendor'].value_counts().sort_values(ascending=False).head(10).plot.bar()
plt.show()

# %%
plt.figure(figsize =(20,10))
plt.subplot(221)
th_2020.groupby('product_service group')['account amount'].sum().plot.pie()
plt.subplot(223)
th_2021.groupby('product_service group')['account amount'].sum().plot.pie()
plt.show()

# %%
th_2020['voucher date'] = pd.to_datetime(th_2020['voucher date']).dt.month

# %%
th_2021['voucher date'] = pd.to_datetime(th_2021['voucher date']).dt.month

# %%
#spend amount each month
plt.figure(figsize =(15,10))
plt.subplot(221)
th_2020.groupby('voucher date')['account amount'].sum().plot.line()
plt.subplot(222)
th_2021.groupby('voucher date')['account amount'].sum().plot.line()
plt.show()

# %%
#number of invoice each month
plt.figure(figsize =(15,10))
plt.subplot(221)
th_2020.groupby('voucher date')['vendor'].value_counts().plot.line()
plt.subplot(222)
th_2021.groupby('voucher date')['vendor'].value_counts().plot.line()
plt.show()

# %%
# number of invoice
plt.figure(figsize =(15,10))
th.groupby('voucher date')['vendor'].value_counts().plot.line()
plt.show()

# %%
# spend
plt.figure(figsize =(15,10))
th.groupby('voucher date')['account amount'].sum().plot.line()
plt.show()
